# %%
import time
from Chem2D import *
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle
# %matplotlib inline
#%config InlineBackend.figure_format='retina'
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numba/decorators.py:142: RuntimeWarning: Caching is not available when the 'parallel' target is in use. Caching is now being disabled to allow execution to continue.
#   warnings.warn(msg, RuntimeWarning)

# %%
bound = 15
res = 20

# %%
print("Estimated time:", (1.2*res**3)/100, "seconds...")
result = hydrogen_wave_func_cross(3,1,0,bound,res,res,res)
print("Generate data took", time.time()-start, "seconds")
print("Estimated time:", (1.2*res**3)/100, "seconds...")
result = hydrogen_wave_func_cross(3,1,0,bound,res,res,res)
print("Generate data took", time.time()-start, "seconds")

# %%
pickle.dump(result, open("3.1.0."+str(bound)+"."+str(res)+"_cross.p", "wb"))

# %%
result = pickle.load(open("3.1.0."+str(bound)+"."+str(res)+"_cross.p", "rb"))
x,y,z,mag,mag_true = result

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')
cm_c = plt.get_cmap("plasma")
colors = mag_true*1000
start = time.time()
print("Start plotting...")
for i in range(0,len(mag)):
    for j in range (0,len(mag)):
        for k in range (0,len(mag)):
            plot_3d = ax.scatter(x[i][j][k],y[i][j][k],z[i][j][k], marker="o", c=[colors[i][j][k]],cmap=cm_c, alpha=(mag[i][j][k]/np.amax(mag)))
#plt.colorbar(plot_3d)
limit = bound*1.2
ax.set_xlim3d(-limit, limit)
ax.set_ylim3d(-limit,limit)
ax.set_zlim3d(-limit,limit)
ax.elev = 0
ax.azim = 0
print("Plotting took", time.time()-start, "seconds")
print("Rendering...")
plt.show()
# Out:
# Start plotting...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/core/numeric.py:544: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# Plotting took 18.434043884277344 seconds
# Rendering...
